# %%
from paho.mqtt import client as mqtt_client
import random
from datetime import datetime
from adtk.detector import SeasonalAD
import matplotlib as plt
from adtk.visualization import plot
import json
import csv
import pandas as pd
from adtk.data import validate_series

# %%
print(datetime.now())
# Out:
# 2024-03-22 21:19:27.045324

# %%
broker = 'broker.emqx.io'
port = 1883
topic = "move_id/AA"
client_id = ''

message_counter = 0  

def append_to_csv(data):
    with open('data_not_normal.csv', mode='a', newline='') as file:
        writer = csv.writer(file)

        # Check if the file is empty and write header if it is
        if file.tell() == 0:
            writer.writerow(['date', 'x', 'y', 'z'])

        writer.writerow(data)


def connect_mqtt() -> mqtt_client:
    def on_connect(client, userdata, flags, rc):
        if rc == 0:
            print("Connected to MQTT Broker!")
        else:
            print("Failed to connect, return code %d\n", rc)

    client = mqtt_client.Client(mqtt_client.CallbackAPIVersion.VERSION1,client_id)
    client.on_connect = on_connect
    client.connect(broker, port)
    return client


def subscribe(client: mqtt_client):
    def on_message(client, userdata, msg):
        global message_counter  
        time = datetime.now()
        data = json.loads(msg.payload.decode())
        
        
        x = float(data['accelerometerSensor']['x'])
        y = float(data['accelerometerSensor']['y'])
        z = float(data['accelerometerSensor']['z'])
        
        
        append_to_csv([time, x, y, z])
        
        print(f"Received `{msg.payload.decode()}` from `{msg.topic}` topic")
        
        message_counter += 1 
        
        if message_counter >= 120:
            print("Received 120 messages, stopping the run.")
            client.disconnect()  
            client.loop_stop()    

    client.subscribe(topic)
    client.on_message = on_message


def run():
    client = connect_mqtt()
    subscribe(client)
    client.loop_forever()


if __name__ == '__main__':
    run()
# Out:
# C:\Users\hugod\AppData\Local\Temp\ipykernel_19108\2298265339.py:26: DeprecationWarning: Callback API version 1 is deprecated, update to latest version
#   client = mqtt_client.Client(mqtt_client.CallbackAPIVersion.VERSION1,client_id)
# Connected to MQTT Broker!
# Received `{"accelerometerSensor":{"x":"6.64","y":"-0.48","z":"-6.96"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"7.71","y":"0.32","z":"-5.89"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"8.59","y":"0.74","z":"-4.61"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"9.16","y":"0.9","z":"-3.38"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"8.92","y":"1.66","z":"3.61"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"8.41","y":"1.73","z":"4.71"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"8.23","y":"1.54","z":"5.21"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"7.93","y":"1.71","z":"5.44"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"7.45","y":"1.69","z":"6.33"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"7.29","y":"1.72","z":"6.33"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"7.68","y":"1.76","z":"5.76"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"7.84","y":"1.74","z":"5.62"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"7.83","y":"1.48","z":"5.75"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"7.31","y":"1.62","z":"6.34"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"7.2","y":"1.66","z":"6.42"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"7.02","y":"1.61","z":"6.67"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"7.06","y":"1.52","z":"6.63"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"7.15","y":"1.53","z":"6.54"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"7.19","y":"1.58","z":"6.46"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"7.1","y":"1.59","z":"6.56"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"7.13","y":"1.5","z":"6.55"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"7.03","y":"1.59","z":"6.66"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"6.93","y":"1.56","z":"6.73"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"6.93","y":"1.56","z":"6.74"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"7
}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"3.01","y":"-9.32","z":"0.29"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"2.65","y":"-9.27","z":"-1.37"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"3.39","y":"-9.1","z":"0.73"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"3.33","y":"-9.23","z":"0.48"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"2.76","y":"-9.28","z":"-0.7"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"3.8","y":"-9.55","z":"-0.26"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"2.96","y":"-9.51","z":"-0.18"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"4.12","y":"-7.77","z":"0.89"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"3.02","y":"-9.36","z":"0.3"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"3.62","y":"-9.11","z":"-1.25"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"1.03","y":"-9.75","z":"0.38"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"-2.46","y":"-11.38","z":"0.79"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"3.24","y":"-9.16","z":"0.38"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"2.92","y":"-9.35","z":"0.67"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"1.55","y":"-9.45","z":"0.32"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"2.39","y":"-9.45","z":"0.49"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"-0.26","y":"-10.42","z":"0.47"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"3.2","y":"-9.23","z":"0.92"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"1.97","y":"-9.25","z":"-1.9"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"2.59","y":"-9.42","z":"0.06"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"2.9","y":"-9.3","z":"0.29"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"2.52","y":"-9.43","z":"-2.08"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"3.88","y":"-8.94","z":"0.59"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"3.98","y":"-8.95","z":"0.17"}}` from `move_id/AA` topic
# Received `{"accelerometerSensor":{"x":"2.08","y":"-9.63","z":"-0.24"}}` from `move_id/AA` topic
# Received 120 messages, stopping the run.

# %%
data = pd.read_csv("sleeping_data_not_normal.csv")


data['date'] = pd.to_datetime(data['date'])
data = data.set_index("date")

# Select the 'x' column
data = data["x"]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 data = pd.read_csv("sleeping_data_not_normal.csv")
#       4 data['date'] = pd.to_datetime(data['date'])
#       5 data = data.set_index("date")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sleeping_data_not_normal.csv'

# %%
print(data)
# Out:
# date
# 2024-03-22 21:14:26.927464    6.64
# 2024-03-22 21:14:27.334157    7.71
# 2024-03-22 21:14:28.342504    8.59
# 2024-03-22 21:14:29.333043    9.16
# 2024-03-22 21:14:30.315541    8.92
#                               ...
# 2024-03-22 21:16:21.312772    2.90
# 2024-03-22 21:16:22.528336    2.52
# 2024-03-22 21:16:23.259309    3.88
# 2024-03-22 21:16:24.290579    3.98
# 2024-03-22 21:16:25.502654    2.08
# Name: x, Length: 120, dtype: float64

# %%
s_train = validate_series(data)

# %%
from adtk.detector import OutlierDetector
from sklearn.neighbors import LocalOutlierFactor

# Initialize Outlier Detector with LocalOutlierFactor
outlier_detector = OutlierDetector(LocalOutlierFactor(contamination=0.01))

# Convert s_train to a DataFrame
s_train_df = s_train.to_frame()

# Fit and detect anomalies on s_train_df
anomalies = outlier_detector.fit_detect(s_train_df)

# Convert anomalies to DataFrame
anomalies_df = anomalies.to_frame()

# %%
import matplotlib.pyplot as plt

# Plot the time series data
plt.figure(figsize=(10, 6))
plt.plot(s_train_df.index, s_train_df.values, label='Time Series Data', color='blue')

# Highlight anomalies
anomalies_indices = anomalies[anomalies == True].index
plt.scatter(anomalies_indices, s_train_df.loc[anomalies_indices], color='red', label='Anomalies')

# Customize plot
plt.title('Time Series Data with Anomalies')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()
